# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
from matplotlib import rc
rc("font", family = "Malgun Gothic")
plt.rcparams["axes.unicode_minus"] = False
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\GitHub\Programming-Basics\FINAL EXAM\Week 13\Section\Section_15.ipynb Cell 2' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/GitHub/Programming-Basics/FINAL%20EXAM/Week%2013/Section/Section_15.ipynb#ch0000003?line=0'>1</a> from matplotlib import rc
#       <a href='vscode-notebook-cell:/d%3A/GitHub/Programming-Basics/FINAL%20EXAM/Week%2013/Section/Section_15.ipynb#ch0000003?line=1'>2</a> rc("font", family = "Malgun Gothic")
# ----> <a href='vscode-notebook-cell:/d%3A/GitHub/Programming-Basics/FINAL%20EXAM/Week%2013/Section/Section_15.ipynb#ch0000003?line=2'>3</a> plt.rcparams["axes.unicode_minus"] = False
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'rcparams'

# %%
x = np.arange(0, 10, 0.1)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.figure(figsize = (10, 6))
x = np.arange(0, 10, 0.1)
plt.plot(x, np.sin(x), label = "sin")
plt.plot(x, np.cos(x), label = "cos")
plt.title("Example of sinewave")
plt.grid()
plt.legend()
plt.xlabel("Time")
plt.ylabel("Amplitude")
# Out:
# Text(0, 0.5, 'Amplitude')
# c:\Users\KMS\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\KMS\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
